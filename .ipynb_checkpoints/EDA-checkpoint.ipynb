# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

# %%
DATA_PATH = './IDN2015_Public_Use_national.csv'
df_raw = pd.read_csv(DATA_PATH)
df_raw.shape
# Out:
# (11142, 141)

# %% [markdown]
# # Kenalan ke dataset

# %%
df_raw.head()
# Out:
#     Q1   Q2   Q3    Q4    Q5   Q6   Q7   Q8   Q9  Q10  ...  qnnotb2g  \
# 0  1.0  1.0  1.0  1.57  41.0  3.0  1.0  4.0  1.0  8.0  ...       1.0
# 1  3.0  1.0  1.0  1.61  54.0  1.0  1.0  5.0  1.0  1.0  ...       1.0
# 2  2.0  2.0  1.0  1.52  46.0  3.0  5.0  4.0  1.0  1.0  ...       1.0
# 3  3.0  2.0  1.0  1.46  58.0  1.0  4.0  4.0  3.0  2.0  ...       1.0
# 4  2.0  2.0  1.0  1.47  48.0  1.0  3.0  5.0  1.0  1.0  ...       1.0
#
#    qnbcanyg  qnc1g  qnpa5g  qnpa7g  qnpe3g  qnpe5g     weight    stratum  psu
# 0       NaN    NaN     2.0     2.0     2.0     2.0  1895.5103  201501012   25
# 1       NaN    NaN     2.0     2.0     2.0     2.0  1895.5103  201501012   25
# 2       NaN    NaN     2.0     2.0     2.0     2.0  1709.8502  201501012   25
# 3       NaN    NaN     2.0     2.0     1.0     2.0  1709.8502  201501012   25
# 4       NaN    NaN     2.0     2.0     2.0     2.0  1709.8502  201501012   25
#
# [5 rows x 141 columns]

# %%
# Rangkuman missing value dataset
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw) * 100).round(2)
missing_df = pd.DataFrame({
    'Jumlah Missing': missing,
    'Persentase (%)': missing_pct
}).sort_values('Persentase (%)', ascending=False)

print('Kolom dengan missing value terbanyak (top 20):')
print(missing_df[missing_df['Jumlah Missing'] > 0].head(20))

print(f'\nTotal kolom dengan missing value : {(missing > 0).sum()}')
print(f'Total kolom tanpa missing value  : {(missing == 0).sum()}')
# Out:
# Kolom dengan missing value terbanyak (top 20):
#           Jumlah Missing  Persentase (%)
# qnbcanyg           11012           98.83
# QN45               10962           98.38
# QN47               10951           98.29
# QN48               10936           98.15
# QN40               10871           97.57
# qnc1g              10867           97.53
# qnc2g              10678           95.84
# QN37               10651           95.59
# QN36               10526           94.47
# QN34               10230           91.81
# QN31                9769           87.68
# QN21                9317           83.62
# QN28                8908           79.95
# QN18                8799           78.97
# QN19                8666           77.78
# QN44                1613           14.48
# Q44                 1613           14.48
# Q47                 1268           11.38
# QN17                1113            9.99
# Q17                 1113            9.99
#
# Total kolom dengan missing value : 138
# ...

# %%
q_cols = [c for c in df_raw.columns if c.startswith('Q') and not c.startswith('QN')]

# Bar plot persentase missing per kolom Q
missing_q = missing_pct[q_cols].sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(14, 4))
missing_q.plot(kind='bar', ax=ax, color='steelblue', edgecolor='white')
ax.set_title('Persentase Missing Value per Variabel (Q1–Q58)')
ax.set_ylabel('Persentase (%)')
ax.set_xlabel('Variabel')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pemetaan key variable

# %%
VAR_MAP = {
    # DEMOGRAFIS
    'Q1':  'Usia (1=≤11thn ... 8=≥18thn)',
    'Q2':  'Jenis kelamin (1=Laki-laki, 2=Perempuan)',
    'Q3':  'Kelas (1=Kelas7 ... 6=Kelas12)',
    'Q4':  'Tinggi badan (meter)',
    'Q5':  'Berat badan (kg)',
    'Q7':  'Sering lapar/kurang pangan (1=Tidak pernah ... 5=Selalu)',

    # MENTAL HEALTH
    'Q38': 'Perasaan kesepian — 12 bulan terakhir (1=Tidak pernah ... 4=Seringkali)',
    'Q39': 'Khawatir sampai tidak bisa tidur — 12 bulan terakhir (1=Tidak pernah ... 4=Seringkali)',
    'Q40': 'Pernah berpikir serius untuk bunuh diri (1=Tidak pernah ... >1=Pernah)',
    'Q41': 'Pernah membuat rencana bunuh diri (1=Tidak/0 ... 5=5+ kali)',
    'Q42': 'Jumlah percobaan bunuh diri (1=0 kali, 2=1 kali, ...)',
    'Q43': 'Jumlah teman dekat (1=0, 2=1, 3=2, 4=3 atau lebih)',

    # BULLYING & KEKERASAN
    'Q22': 'Jumlah kali diserang fisik — 12 bulan (1=0 kali ... 5=6-7 kali+)',
    'Q23': 'Jumlah perkelahian fisik — 12 bulan (1=0 kali ... 5=6+ kali)',
    'Q29': 'Hari di-bully — 30 hari terakhir (1=0 hari, 2=1-2 hari, ...)',
    'Q30': 'Cara di-bully paling sering',
    'Q32': 'Disakiti oleh pacar secara fisik (1=Tidak punya pacar, 2=Ya, 3=Tidak)',
    'Q33': 'Disakiti oleh guru secara fisik (1=Ya, 2=Tidak)',
    'Q34': 'Hari tidak sekolah karena takut (1=0 hari ... 5=6+ hari)',
    'Q35': 'Pernah dipaksa berhubungan seksual',

    # PENGGUNAAN ZAT
    'Q45': 'Usia pertama kali merokok',
    'Q46': 'Hari merokok — 30 hari terakhir (1=0 hari, 2=1-2 hari, ...)',
    'Q51': 'Usia pertama kali minum alkohol',
    'Q52': 'Hari minum alkohol — 30 hari terakhir',
    'Q56': 'Berapa kali mabuk seumur hidup',
    'Q58': 'Usia pertama kali menggunakan narkoba',

    # VARIABEL DERIVED (BINARY: 1=Ya/Berisiko, 2=Tidak)
    'QN38': 'Sering/selalu kesepian [binary]',
    'QN39': 'Sering/selalu khawatir-insomnia [binary]',
    'QN41': 'Pernah mempertimbangkan bunuh diri [binary]',
    'QN42': 'Pernah mencoba bunuh diri [binary]',
    'QN29': 'Di-bully (≥1 hari/bulan) [binary]',
    'QN22': 'Diserang fisik [binary]',
    'QN46': 'Perokok aktif [binary]',
    'QN52': 'Peminum alkohol [binary]',
    'QN58': 'Pengguna narkoba [binary]',
    'qnpe3g': 'Aktif fisik ≥3 hari/minggu [binary]',
    'qnpe5g': 'Aktif fisik ≥5 hari/minggu [binary]',
}

pd.DataFrame.from_dict(VAR_MAP, orient='index', columns=['Deskripsi'])
# Out:
#                                                 Deskripsi
# Q1                           Usia (1=≤11thn ... 8=≥18thn)
# Q2               Jenis kelamin (1=Laki-laki, 2=Perempuan)
# Q3                         Kelas (1=Kelas7 ... 6=Kelas12)
# Q4                                   Tinggi badan (meter)
# Q5                                       Berat badan (kg)
# Q7      Sering lapar/kurang pangan (1=Tidak pernah ......
# Q38     Perasaan kesepian — 12 bulan terakhir (1=Tidak...
# Q39     Khawatir sampai tidak bisa tidur — 12 bulan te...
# Q40     Pernah berpikir serius untuk bunuh diri (1=Tid...
# Q41     Pernah membuat rencana bunuh diri (1=Tidak/0 ....
# Q42     Jumlah percobaan bunuh diri (1=0 kali, 2=1 kal...
# Q43     Jumlah teman dekat (1=0, 2=1, 3=2, 4=3 atau le...
# Q22     Jumlah kali diserang fisik — 12 bulan (1=0 kal...
# Q23     Jumlah perkelahian fisik — 12 bulan (1=0 kali ...
# Q29     Hari di-bully — 30 hari terakhir (1=0 hari, 2=...
# ...
